# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # YOLOv8 Tracking and Counting
#
# ---
#
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/OS5qI9YBkfk)
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/yolov8-tracking-and-counting/)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/notebooks)
#
# Ultralytics YOLOv8 is the latest version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## ⚠️ Disclaimer
#
# YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **23.01.2023** with version **YOLOv8.0.17**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on how to train YOLOv8 Tracking and Counting, concurrently.
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Download video
# - Install YOLOv8
# - Install ByteTrack
# - Install Roboflow Supervision
# - Tracking utils
# - Load pre-trained YOLOv8 model
# - Predict and annotate single frame
# - Predict and annotate whole video
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Tue Jul 11 17:11:58 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Download video

# %%
# %cd {HOME}
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-" -O production_id_4887833 (2160p).mp4 && rm -rf /tmp/cookies.txt
# Out:
# /content
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-" -O production_id_4887833 (2160p).mp4 && rm -rf /tmp/cookies.txt'

# %%
SOURCE_VIDEO_PATH = f"{HOME}/production_id_4887833 (2160p).mp4"

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **23.01.2023** with version **YOLOv8.0.17**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.7/78.2 GB disk)

# %% [markdown]
# ## Install ByteTrack
#
# [ByteTrack](https://github.com/ifzhang/ByteTrack) is great tracker but a bit poorly packaged. We need to jump through some fire hoops to make it work in tandem with [YOLOv8](https://github.com/ultralytics/ultralytics).

# %%
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %% [markdown]
# ## Install Roboflow Supervision

# %%
# !pip install supervision==0.1.0


from IPython import display
display.clear_output()


import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# supervision.__version__: 0.1.0

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %% [markdown]
# ## Tracking utils
#
# Unfortunately, we have to manually match the bounding boxes coming from our model with those created by the tracker.

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %% [markdown]
# ## Load pre-trained YOLOv8 model

# %%
# settings
MODEL = "yolov8x.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients

# %% [markdown]
# ## Predict and annotate single frame

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - car, motorcycle, bus and truck
CLASS_ID = [2, 3, 5, 7]

# %%
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame)
detections = Detections(
    xyxy=results[0].boxes.xyxy.cpu().numpy(),
    confidence=results[0].boxes.conf.cpu().numpy(),
    class_id=results[0].boxes.cls.cpu().numpy().astype(int)
)
# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, confidence, class_id, tracker_id
    in detections
]
# annotate and display frame
frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

# %matplotlib inline
show_frame_in_notebook(frame, (16, 16))
# Out:
# 0: 384x640 3 persons, 22 cars, 1 motorcycle, 3 trucks, 64.0ms
# Speed: 2.8ms preprocess, 64.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Predict and annotate whole video

# %%
# settings
LINE_START = Point(50, 1500)
LINE_END = Point(3840-50, 1500)

TARGET_VIDEO_PATH = f"{HOME}/vehicle-counting-result.mp4"

# %%
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# VideoInfo(width=3840, height=2160, fps=60, total_frames=339)

# %%
from tqdm.notebook import tqdm


# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter = LineCounter(start=LINE_START, end=LINE_END)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
line_annotator = LineCounterAnnotator(thickness=4, text_thickness=4, text_scale=2)

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):
        # model prediction on single frame and conversion to supervision Detections
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        # updating line counter
        line_counter.update(detections=detections)
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        line_annotator.annotate(frame=frame, line_counter=line_counter)
        sink.write_frame(frame)
# Out:
#   0%|          | 0/339 [00:00<?, ?it/s]
# 0: 384x640 3 persons, 22 cars, 1 motorcycle, 3 trucks, 64.2ms
# Speed: 3.7ms preprocess, 64.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 23 cars, 2 trucks, 66.1ms
# Speed: 3.3ms preprocess, 66.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 24 cars, 2 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 22 cars, 1 motorcycle, 3 trucks, 63.4ms
# Speed: 3.6ms preprocess, 63.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 3 trucks, 70.5ms
# Speed: 3.4ms preprocess, 70.5ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 motorcycle, 1 bus, 3 trucks, 67.8ms
# Speed: 6.0ms preprocess, 67.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 motorcycle, 2 trucks, 67.4ms
# Speed: 8.8ms preprocess, 67.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 bus, 4 trucks, 65.8ms
# Speed: 8.1ms preprocess, 65.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 3 trucks, 63.3ms
# Speed: 3.5ms preprocess, 63.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 bus, 4 trucks, 66.7ms
# Speed: 5.3ms preprocess, 66.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 3 trucks, 1 traffic light, 63.2ms
# Speed: 5.8ms preprocess, 63.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25 cars, 2 trucks, 1 traffic light, 65.2ms
# Speed: 8.7ms preprocess, 65.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 26 cars, 2 trucks, 66.8ms
# Speed: 4.6ms preprocess, 66.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 26 cars, 1 bus, 2 trucks, 1 traffic light, 63.3ms
# Speed: 3.6ms preprocess, 63.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 27 cars, 1 bus, 3 trucks, 1 traffic light, 66.6ms
# Speed: 4.0ms preprocess, 66.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 27 cars, 1 bus, 3 trucks, 72.6ms
# Speed: 3.5ms preprocess, 72.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 28 cars, 3 trucks, 1 traffic light, 63.2ms
# Speed: 3.6ms preprocess, 63.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 27 cars, 2 trucks, 1 traffic light, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 25 cars, 2 trucks, 63.3ms
# Speed: 3.3ms preprocess, 63.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 26 cars, 2 trucks, 69.3ms
# Speed: 4.0ms preprocess, 69.3ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 27 cars, 2 trucks, 1 traffic light, 65.1ms
# Speed: 3.3ms preprocess, 65.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 27 cars, 1 bus, 2 trucks, 1 traffic light, 68.1ms
# Speed: 3.6ms preprocess, 68.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 26 cars, 1 bus, 2 trucks, 1 traffic light, 63.4ms
# Speed: 3.4ms preprocess, 63.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 26 cars, 2 trucks, 64.3ms
# Speed: 5.4ms preprocess, 64.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 25 cars, 2 trucks, 63.1ms
# Speed: 3.9ms preprocess, 63.1ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 25 cars, 2 trucks, 79.5ms
# Speed: 7.5ms preprocess, 79.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 26 cars, 1 motorcycle, 2 trucks, 68.1ms
# Speed: 4.2ms preprocess, 68.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 26 cars, 1 motorcycle, 2 trucks, 63.2ms
# Speed: 3.4ms preprocess, 63.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 26 cars, 1 motorcycle, 1 bus, 2 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 26 cars, 1 motorcycle, 1 bus, 2 trucks, 72.8ms
# Speed: 3.4ms preprocess, 72.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 1 bus, 2 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 1 motorcycle, 2 buss, 2 trucks, 64.1ms
# Speed: 7.4ms preprocess, 64.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 motorcycle, 3 trucks, 1 traffic light, 68.7ms
# Speed: 3.5ms preprocess, 68.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 motorcycle, 2 trucks, 2 traffic lights, 71.5ms
# Speed: 9.2ms preprocess, 71.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.6ms
# Speed: 3.5ms preprocess, 63.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22 cars, 1 motorcycle, 2 trucks, 67.2ms
# Speed: 3.4ms preprocess, 67.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23 cars, 1 motorcycle, 2 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 26 cars, 1 motorcycle, 2 trucks, 1 traffic light, 64.9ms
# Speed: 3.6ms preprocess, 64.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 2 trucks, 1 traffic light, 63.2ms
# Speed: 3.6ms preprocess, 63.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.4ms
# Speed: 3.3ms preprocess, 63.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 2 trucks, 1 traffic light, 65.0ms
# Speed: 11.7ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.2ms
# Speed: 3.5ms preprocess, 63.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 2 trucks, 1 traffic light, 65.3ms
# Speed: 4.5ms preprocess, 65.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 2 trucks, 63.2ms
# Speed: 4.2ms preprocess, 63.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 2 trucks, 64.9ms
# Speed: 3.3ms preprocess, 64.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24 cars, 1 motorcycle, 2 trucks, 67.1ms
# Speed: 5.4ms preprocess, 67.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23 cars, 1 motorcycle, 2 trucks, 63.1ms
# Speed: 5.0ms preprocess, 63.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24 cars, 1 motorcycle, 2 trucks, 63.4ms
# Speed: 5.3ms preprocess, 63.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25 cars, 1 motorcycle, 2 trucks, 63.5ms
# Speed: 3.4ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 1 motorcycle, 2 trucks, 63.4ms
# Speed: 4.5ms preprocess, 63.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 1 motorcycle, 2 trucks, 68.9ms
# Speed: 3.4ms preprocess, 68.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 1 motorcycle, 2 trucks, 65.7ms
# Speed: 3.4ms preprocess, 65.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 1 motorcycle, 2 trucks, 63.2ms
# Speed: 3.9ms preprocess, 63.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 1 bus, 2 trucks, 65.6ms
# Speed: 6.1ms preprocess, 65.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 motorcycle, 1 bus, 2 trucks, 68.9ms
# Speed: 3.3ms preprocess, 68.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23 cars, 1 motorcycle, 1 bus, 2 trucks, 64.7ms
# Speed: 3.7ms preprocess, 64.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 motorcycle, 1 bus, 2 trucks, 65.1ms
# Speed: 10.2ms preprocess, 65.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 bus, 2 trucks, 63.4ms
# Speed: 3.2ms preprocess, 63.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 bus, 2 trucks, 63.3ms
# Speed: 3.6ms preprocess, 63.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 3 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23 cars, 1 bus, 3 trucks, 63.4ms
# Speed: 4.0ms preprocess, 63.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 bus, 2 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 bus, 2 trucks, 63.5ms
# Speed: 5.1ms preprocess, 63.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 21 cars, 1 bus, 2 trucks, 63.1ms
# Speed: 4.3ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 21 cars, 1 bus, 2 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 21 cars, 1 bus, 2 trucks, 63.6ms
# Speed: 3.7ms preprocess, 63.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 23 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 23 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 63.1ms
# Speed: 3.6ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 23 cars, 2 motorcycles, 1 truck, 63.3ms
# Speed: 3.8ms preprocess, 63.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 1 truck, 1 traffic light, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 2 trucks, 1 traffic light, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 2 trucks, 63.1ms
# Speed: 3.6ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 2 trucks, 63.9ms
# Speed: 3.8ms preprocess, 63.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 25 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.1ms
# Speed: 3.9ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 1 motorcycle, 1 truck, 63.2ms
# Speed: 4.5ms preprocess, 63.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 1 truck, 63.1ms
# Speed: 4.0ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 2 trucks, 64.9ms
# Speed: 3.5ms preprocess, 64.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 bus, 3 trucks, 63.6ms
# Speed: 6.2ms preprocess, 63.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 bus, 2 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 26 cars, 1 bus, 2 trucks, 1 traffic light, 63.2ms
# Speed: 3.7ms preprocess, 63.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 25 cars, 1 bus, 2 trucks, 1 traffic light, 63.2ms
# Speed: 3.5ms preprocess, 63.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 25 cars, 1 bus, 2 trucks, 63.6ms
# Speed: 3.8ms preprocess, 63.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 bus, 3 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 24 cars, 1 bus, 2 trucks, 63.1ms
# Speed: 3.8ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 bus, 2 trucks, 63.2ms
# Speed: 3.6ms preprocess, 63.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 bus, 2 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 22 cars, 1 bus, 3 trucks, 63.1ms
# Speed: 5.7ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 23 cars, 1 bus, 3 trucks, 63.4ms
# Speed: 3.6ms preprocess, 63.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 23 cars, 2 trucks, 63.2ms
# Speed: 3.6ms preprocess, 63.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 23 cars, 1 motorcycle, 1 bus, 2 trucks, 63.4ms
# Speed: 3.4ms preprocess, 63.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 bus, 3 trucks, 63.1ms
# Speed: 3.7ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 bus, 2 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 bus, 2 trucks, 1 traffic light, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 motorcycle, 1 bus, 3 trucks, 2 traffic lights, 58.1ms
# Speed: 3.7ms preprocess, 58.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 23 cars, 1 motorcycle, 1 bus, 3 trucks, 1 traffic light, 1 skis, 58.0ms
# Speed: 3.7ms preprocess, 58.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 3 trucks, 1 traffic light, 1 skis, 58.0ms
# Speed: 7.6ms preprocess, 58.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 23 cars, 1 motorcycle, 2 trucks, 1 traffic light, 62.0ms
# Speed: 3.6ms preprocess, 62.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 23 cars, 1 motorcycle, 4 trucks, 1 traffic light, 58.2ms
# Speed: 3.5ms preprocess, 58.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 motorcycle, 3 trucks, 1 traffic light, 58.0ms
# Speed: 3.5ms preprocess, 58.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 2 motorcycles, 3 trucks, 58.2ms
# Speed: 5.5ms preprocess, 58.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 motorcycle, 3 trucks, 58.0ms
# Speed: 3.5ms preprocess, 58.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 motorcycle, 2 trucks, 58.0ms
# Speed: 3.7ms preprocess, 58.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22 cars, 1 motorcycle, 3 trucks, 1 traffic light, 63.1ms
# Speed: 6.6ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 2 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 motorcycle, 2 trucks, 67.0ms
# Speed: 3.3ms preprocess, 67.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 26 cars, 1 motorcycle, 2 trucks, 63.4ms
# Speed: 3.6ms preprocess, 63.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 2 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 2 trucks, 63.2ms
# Speed: 3.4ms preprocess, 63.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25 cars, 2 trucks, 1 umbrella, 63.1ms
# Speed: 3.2ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 motorcycle, 2 trucks, 63.5ms
# Speed: 3.5ms preprocess, 63.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 1 bus, 3 trucks, 1 traffic light, 68.5ms
# Speed: 4.2ms preprocess, 68.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.2ms
# Speed: 3.1ms preprocess, 63.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 26 cars, 2 trucks, 63.3ms
# Speed: 3.3ms preprocess, 63.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 2 trucks, 1 traffic light, 63.7ms
# Speed: 3.7ms preprocess, 63.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 2 trucks, 1 traffic light, 63.2ms
# Speed: 3.4ms preprocess, 63.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 26 cars, 2 trucks, 63.1ms
# Speed: 7.9ms preprocess, 63.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 2 trucks, 63.1ms
# Speed: 4.1ms preprocess, 63.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 26 cars, 2 trucks, 63.1ms
# Speed: 4.3ms preprocess, 63.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 2 trucks, 1 traffic light, 64.9ms
# Speed: 8.4ms preprocess, 64.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 2 trucks, 63.1ms
# Speed: 3.6ms preprocess, 63.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 25 cars, 2 trucks, 64.1ms
# Speed: 3.5ms preprocess, 64.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22 cars, 2 trucks, 63.1ms
# Speed: 3.8ms preprocess, 63.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 2 trucks, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 2 trucks, 69.2ms
# Speed: 3.4ms preprocess, 69.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 bus, 2 trucks, 63.2ms
# Speed: 3.6ms preprocess, 63.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 2 trucks, 63.1ms
# Speed: 3.8ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22 cars, 2 trucks, 63.1ms
# Speed: 4.0ms preprocess, 63.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 2 trucks, 63.1ms
# Speed: 3.9ms preprocess, 63.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 1 motorcycle, 3 trucks, 71.7ms
# Speed: 7.0ms preprocess, 71.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23 cars, 1 motorcycle, 1 bus, 3 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23 cars, 1 motorcycle, 1 bus, 3 trucks, 1 traffic light, 63.2ms
# Speed: 6.3ms preprocess, 63.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 21 cars, 2 motorcycles, 1 bus, 2 trucks, 79.8ms
# Speed: 12.0ms preprocess, 79.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22 cars, 2 motorcycles, 3 trucks, 66.0ms
# Speed: 3.3ms preprocess, 66.0ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 motorcycle, 2 trucks, 63.2ms
# Speed: 3.4ms preprocess, 63.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 21 cars, 2 motorcycles, 3 trucks, 1 traffic light, 63.1ms
# Speed: 3.2ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 21 cars, 1 motorcycle, 2 trucks, 72.4ms
# Speed: 3.4ms preprocess, 72.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 22 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.2ms
# Speed: 4.6ms preprocess, 63.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 21 cars, 2 motorcycles, 2 trucks, 63.2ms
# Speed: 3.6ms preprocess, 63.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 22 cars, 1 motorcycle, 2 trucks, 63.1ms
# Speed: 5.0ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 22 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22 cars, 1 motorcycle, 2 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 2 trucks, 63.3ms
# Speed: 3.8ms preprocess, 63.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 21 cars, 1 motorcycle, 3 trucks, 63.2ms
# Speed: 3.5ms preprocess, 63.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 21 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.2ms
# Speed: 3.4ms preprocess, 63.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22 cars, 1 motorcycle, 3 trucks, 1 traffic light, 65.4ms
# Speed: 3.2ms preprocess, 65.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 2 motorcycles, 2 trucks, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25 cars, 1 motorcycle, 2 trucks, 63.1ms
# Speed: 3.6ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 bus, 2 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 1 bus, 3 trucks, 1 traffic light, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons,
4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23 cars, 2 motorcycles, 3 trucks, 1 traffic light, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22 cars, 2 motorcycles, 3 trucks, 1 traffic light, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24 cars, 2 motorcycles, 1 bus, 1 truck, 63.1ms
# Speed: 4.0ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24 cars, 3 motorcycles, 3 trucks, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23 cars, 3 motorcycles, 2 trucks, 63.3ms
# Speed: 3.4ms preprocess, 63.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23 cars, 3 motorcycles, 1 bus, 2 trucks, 63.1ms
# Speed: 5.0ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23 cars, 3 motorcycles, 1 bus, 1 truck, 63.2ms
# Speed: 3.4ms preprocess, 63.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24 cars, 3 motorcycles, 1 bus, 1 truck, 1 traffic light, 63.3ms
# Speed: 3.5ms preprocess, 63.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22 cars, 3 motorcycles, 1 bus, 1 truck, 1 traffic light, 63.1ms
# Speed: 4.6ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 21 cars, 2 motorcycles, 1 bus, 4 trucks, 1 traffic light, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23 cars, 3 motorcycles, 5 trucks, 1 traffic light, 63.5ms
# Speed: 3.4ms preprocess, 63.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 19 cars, 2 motorcycles, 5 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 20 cars, 3 motorcycles, 3 trucks, 63.1ms
# Speed: 3.7ms preprocess, 63.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 22 cars, 3 motorcycles, 2 trucks, 1 traffic light, 63.2ms
# Speed: 3.4ms preprocess, 63.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 21 cars, 3 motorcycles, 1 truck, 1 traffic light, 63.3ms
# Speed: 3.4ms preprocess, 63.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 20 cars, 2 motorcycles, 2 trucks, 1 traffic light, 63.2ms
# Speed: 4.4ms preprocess, 63.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 22 cars, 2 motorcycles, 3 trucks, 1 traffic light, 63.2ms
# Speed: 3.5ms preprocess, 63.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 19 cars, 1 motorcycle, 3 trucks, 1 traffic light, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.5ms
# Speed: 3.3ms preprocess, 63.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 1 motorcycle, 4 trucks, 1 traffic light, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 22 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 21 cars, 1 motorcycle, 1 bus, 3 trucks, 1 skis, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22 cars, 1 motorcycle, 2 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23 cars, 2 motorcycles, 1 bus, 2 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22 cars, 2 motorcycles, 1 bus, 3 trucks, 1 traffic light, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 21 cars, 3 motorcycles, 1 bus, 3 trucks, 1 traffic light, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 21 cars, 2 motorcycles, 1 bus, 1 truck, 63.1ms
# Speed: 3.8ms preprocess, 63.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 3 motorcycles, 1 bus, 1 truck, 63.1ms
# Speed: 3.6ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 3 motorcycles, 1 bus, 3 trucks, 63.1ms
# Speed: 3.7ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22 cars, 2 motorcycles, 1 bus, 2 trucks, 63.1ms
# Speed: 3.8ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24 cars, 3 motorcycles, 1 bus, 4 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 26 cars, 4 motorcycles, 4 trucks, 63.2ms
# Speed: 5.2ms preprocess, 63.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22 cars, 3 motorcycles, 1 bus, 3 trucks, 63.4ms
# Speed: 3.5ms preprocess, 63.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22 cars, 3 motorcycles, 4 trucks, 63.4ms
# Speed: 3.3ms preprocess, 63.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23 cars, 3 motorcycles, 2 trucks, 1 traffic light, 1 skis, 64.8ms
# Speed: 3.5ms preprocess, 64.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23 cars, 2 motorcycles, 3 trucks, 68.3ms
# Speed: 3.7ms preprocess, 68.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23 cars, 3 motorcycles, 1 bus, 3 trucks, 1 traffic light, 63.3ms
# Speed: 5.6ms preprocess, 63.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23 cars, 3 motorcycles, 1 bus, 3 trucks, 1 traffic light, 63.1ms
# Speed: 4.0ms preprocess, 63.1ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23 cars, 2 motorcycles, 4 trucks, 63.1ms
# Speed: 3.2ms preprocess, 63.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 2 motorcycles, 3 trucks, 63.5ms
# Speed: 3.5ms preprocess, 63.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24 cars, 2 motorcycles, 1 bus, 3 trucks, 2 traffic lights, 71.0ms
# Speed: 3.3ms preprocess, 71.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25 cars, 2 motorcycles, 1 bus, 2 trucks, 1 traffic light, 68.5ms
# Speed: 3.7ms preprocess, 68.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22 cars, 2 motorcycles, 1 bus, 3 trucks, 1 traffic light, 64.5ms
# Speed: 3.4ms preprocess, 64.5ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22 cars, 2 motorcycles, 3 trucks, 1 traffic light, 63.1ms
# Speed: 5.4ms preprocess, 63.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22 cars, 2 motorcycles, 4 trucks, 1 traffic light, 63.4ms
# Speed: 4.4ms preprocess, 63.4ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22 cars, 2 motorcycles, 1 bus, 2 trucks, 2 traffic lights, 64.9ms
# Speed: 3.4ms preprocess, 64.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 20 cars, 2 motorcycles, 1 bus, 3 trucks, 2 traffic lights, 63.5ms
# Speed: 3.4ms preprocess, 63.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 23 cars, 2 motorcycles, 3 trucks, 1 traffic light, 69.5ms
# Speed: 3.5ms preprocess, 69.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23 cars, 2 motorcycles, 4 trucks, 63.6ms
# Speed: 3.4ms preprocess, 63.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 19 cars, 2 motorcycles, 4 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 20 cars, 2 motorcycles, 3 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 19 cars, 1 motorcycle, 1 bus, 2 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 20 cars, 2 motorcycles, 3 trucks, 63.1ms
# Speed: 3.6ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 22 cars, 1 motorcycle, 3 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 20 cars, 1 motorcycle, 4 trucks, 63.1ms
# Speed: 3.7ms preprocess, 63.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 20 cars, 1 motorcycle, 2 trucks, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 18 cars, 2 motorcycles, 2 trucks, 63.1ms
# Speed: 3.6ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 19 cars, 1 motorcycle, 2 trucks, 63.2ms
# Speed: 3.4ms preprocess, 63.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 21 cars, 1 motorcycle, 1 bus, 2 trucks, 63.2ms
# Speed: 3.5ms preprocess, 63.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 21 cars, 1 motorcycle, 2 trucks, 63.5ms
# Speed: 3.3ms preprocess, 63.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 22 cars, 1 motorcycle, 3 trucks, 63.1ms
# Speed: 3.8ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 24 cars, 1 motorcycle, 2 trucks, 63.2ms
# Speed: 3.3ms preprocess, 63.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 19 cars, 1 motorcycle, 3 trucks, 63.1ms
# Speed: 4.9ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 17 cars, 1 motorcycle, 3 trucks, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 17 cars, 1 motorcycle, 3 trucks, 63.1ms
# Speed: 3.7ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 20 cars, 1 motorcycle, 2 trucks, 63.1ms
# Speed: 3.8ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 21 cars, 1 motorcycle, 2 trucks, 63.2ms
# Speed: 3.4ms preprocess, 63.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 19 cars, 1 motorcycle, 2 trucks, 1 traffic light, 63.4ms
# Speed: 3.1ms preprocess, 63.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 19 cars, 1 motorcycle, 1 bus, 2 trucks, 63.2ms
# Speed: 3.2ms preprocess, 63.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 21 cars, 2 motorcycles, 1 bus, 2 trucks, 63.2ms
# Speed: 3.2ms preprocess, 63.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
